# %%
import pandas as pd
import numpy as np

# %%
stock_df = pd.read_csv("../../stock_price/stock_price_v2/stock_price_v2.csv",
                       parse_dates=["time"],
                       usecols=["symbol", "time", "close"]
                      )
stock_df.rename(columns={"time": "datetime"}, inplace=True)
stock_df.drop_duplicates(inplace=True)

# check no duplicate datetime per symbol
assert stock_df.groupby("symbol").apply(lambda x: x["datetime"].duplicated().any()).any() == False

# filter datetime
stock_df = stock_df.loc[stock_df["datetime"] >= pd.Timestamp("2022-02-25 08:00:00")]

# create date and time columns
# stock_df["date"] = stock_df["datetime"].dt.normalize()
# stock_df["time"] = stock_df["datetime"].dt.time

# %%
stock_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12187398 entries, 0 to 21989495
# Data columns (total 3 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   datetime  datetime64[ns]
#  1   close     float64
#  2   symbol    object
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 371.9+ MB

# %%
stock_df = stock_df.set_index(["symbol", "datetime"]).sort_index()[["close"]]

stock_df.head()
# Out:
#                                  close
# symbol datetime
# A      2022-02-25 09:35:00  128.007913
#        2022-02-25 09:40:00  128.574232
#        2022-02-25 09:45:00  128.206622
#        2022-02-25 09:50:00  128.653716
#        2022-02-25 09:55:00  128.455007

# %% [markdown]
# ## News

# %%
news_df = pd.read_csv("../combine_pred/combine_pred.csv", parse_dates=["time_published"])

# %%
news_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88167 entries, 0 to 88166
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   index                    88167 non-null  int64
#  1   title                    88167 non-null  object
#  2   url                      88167 non-null  object
#  3   time_published           88167 non-null  datetime64[ns]
#  4   authors                  88167 non-null  object
#  5   summary                  88166 non-null  object
#  6   banner_image             87349 non-null  object
#  7   source                   88167 non-null  object
#  8   category_within_source   20361 non-null  object
#  9   source_domain            88167 non-null  object
#  10  topics                   88167 non-null  object
#  11  overall_sentiment_score  88167 non-null  float64
#  12  overall_sentiment_label  88167 non-null  object
#  13  ticker_sentiment         88167 non-null  object
#  14  company                  88167 non-null  object
#  15  symbol                   88167 non-null  object
#  16  relevance_score          88167 non-null  float64
#  17  ticker_sentiment_score   88167 non-null  float64
#  18  ticker_sentiment_label   88167 non-null  object
#  19  model_input              88167 non-null  object
#  20  lexicon_neg              88167 non-null  float64
#  21  lexicon_neu              88167 non-null  float64
#  22  lexicon_pos              88167 non-null  float64
#  23  lexicon_compound         88167 non-null  float64
#  24  finbertv1_negative       88167 non-null  float64
#  25  finbertv1_neutral        88167 non-null  float64
#  26  finbertv1_positive       88167 non-null  float64
#  27  finbertv2_Negative       88167 non-null  float64
#  28  finbertv2_Neutral        88167 non-null  float64
#  29  finbertv2_Positive       88167 non-null  float64
# dtypes: datetime64[ns](1), float64(13), int64(1), object(15)
# memory usage: 20.2+ MB

# %%
news_df.sample(10)
# Out:
#         index                                              title  \
# 23668   55990  Bitcoin, Ethereum, Dogecoin Spike Amid Risk-On...
# 38066   95936  Want Better Returns? Don?t Ignore These 2 Cons...
# 17015   38703  IDEXX Laboratories Stock Clears Technical Benc...
# 2604     6505  Check Out What Whales Are Doing With TGT - Tar...
# 25298   59787                 Better AI Stock: Amazon vs. Nvidia
# 29962   75848  Hershey  ( NYSE:HSY )  Raised to "Buy" at Stoc...
# 78624  207648  Here's Why Investors Should Retain Generac  ( ...
# 52723  137353  Here's Why Momentum in Lamb Weston  ( LW )  Sh...
# 41688  108058  Johnson & Johnson  ( JNJ )  Outpaces Stock Mar...
# 83948  230621  General Electric  ( GE )  Arm, NTPC Ink MOU on...
#
#                                                      url      time_published  \
# 23668  https://www.benzinga.com/markets/cryptocurrenc... 2023-01-30 02:26:43
# 38066  https://www.zacks.com/stock/news/2032237/want-... 2022-12-26 13:50:08
# 17015  https://www.investors.com/news/idexx-laborator... 2023-01-09 19:37:00
# 2604   https://www.benzinga.com/markets/options/22/10... 2022-10-03 19:21:44
# 25298  https://www.fool.com/investing/2023/03/12/bett... 2023-03-12 12:38:00
# 29962  https://reporter.am/2022/10/13/hershey-nysehsy... 2022-10-13 08:20:44
# 78624  https://www.zacks.com/stock/news/1969756/heres... 2022-08-18 15:11:00
# 52723  https://www.zacks.com/stock/news/1967619/heres... 2022-08-12 12:50:06
# 41688  https://www.zacks.com/stock/news/2071013/johns... 2023-03-27 21:45:19
# 83948  https://www.zacks.com/stock/news/1989928/gener... 2022-10-10 18:27:00
#
#                                                  authors  \
# 23668                                  ['Mehab Qureshi']
# 38066                      ['Zacks Investment Research']
# 17015  ["INVESTOR'S BUSINESS DAILY", 'JULIE MAK', "In...
# 2604                               ['Benzinga Insights']
# 25298                                      ['Dani Cook']
# 29962                              ['AM Reporter Staff']
# 78624                      ['Zacks Investment Research']
# 52723                      ['Zacks Investment Research']
# 41688                      ['Zacks Investment Research']
# 83948                      ['Zacks Investment Research']
#
#                                                  summary  \
# 23668  Major coins traded in the green on Sunday even...
# 38066  Why investors should use the Zacks Earnings ES...
# 17015  IDEXX Laboratories Stock Clears Technical Benc...
# 2604   Someone with a lot of money to spend has taken...
# 25298  These companies will likely play significant r...
# 29962  StockNews.com upgraded shares of Hershey ( NYS...
# 78624  Generac's (GNRC) performance is gaining from i...
# 52723  Lamb Weston (LW) could be a great choice for i...
# 41688  In the latest trading session, Johnson & Johns...
# 83948  General Electric (GE) arm signs a MOU with Ind...
#
#                                             banner_image  \
# 23668  https://cdn.benzinga.com/files/images/story/20...
# 38066  https://staticx-tuner.zacks.com/images/default...
# 17015  https://www.investors.com/wp-content/uploads/2...
# 2604   https://cdn.benzinga.com/files/images/story/20...
# 25298  https://g.foolcdn.com/image/?url=https%3A%2F%2...
# 29962  https://www.marketbeat.com/scripts/RatingsAndP...
# 78624  https://staticx-tuner.zacks.com/images/article...
# 52723  https://staticx-tuner.zacks.com/images/default...
# 41688  https://staticx-tuner.zacks.com/images/default...
# 83948  https://staticx-tuner.zacks.com/images/article...
#
#                          source category_within_source      source_domain  \
# 23668                  Benzinga                Trading   www.benzinga.com
# 38066          Zacks Commentary                    NaN      www.zacks.com
# 17015  Investors Business Daily                    NaN  www.investors.com
# 2604                   Benzinga                Markets   www.benzinga.com
# 25298               Motley Fool                    NaN       www.fool.com
# 29962             Stocknews.com                    NaN        reporter.am
# 78624          Zacks Commentary                    NaN      www.zacks.com
# 52723          Zacks Commentary                    NaN      www.zacks.com
# 41688          Zacks Commentary                    NaN      www.zacks.com
# 83948          Zacks Commentary                    NaN      www.zacks.com
#
#        ... lexicon_neg  lexicon_neu lexicon_pos lexicon_compound  \
# 23668  ...       0.000        1.000       0.000           0.0000
# 38066  ...       0.143        0.714       0.143           0.0000
# 17015  ...       0.000        1.000       0.000           0.0000
# 2604   ...       0.000        1.000       0.000           0.0000
# 25298  ...       0.000        1.000       0.000           0.0000
# 29962  ...       0.000        1.000       0.000           0.0000
# 78624  ...       0.000        0.750       0.250           0.4588
# 52723  ...       0.000        0.902       0.098           0.4588
# 41688  ...       0.000        1.000       0.000           0.0000
# 83948  ...       0.000        1.000       0.000           0.0000
#
#       finbertv1_negative finbertv1_neutral  finbertv1_positive  \
# 23668           0.019106          0.038927            0.941967
# 38066           0.032257          0.813108            0.154635
# 17015           0.029725          0.047696            0.922579
# 2604            0.049384          0.885959            0.064657
# 25298           0.007341          0.662978            0.329680
# 29962           0.018061          0.090849            0.891090
# 78624           0.013141          0.031615            0.955244
# 52723           0.008214          0.272354            0.719432
# 41688           0.085899          0.020148            0.893953
# 83948           0.013681          0.101140            0.885179
#
#        finbertv2_Negative finbertv2_Neutral finbertv2_Positive
# 23668        7.061056e-04      8.886214e-01       1.106724e-01
# 38066        4.022257e-07      4.205933e-07       9.999992e-01
# 17015        8.556109e-07      9.999988e-01       3.761108e-07
# 2604         1.136416e-02      1.925217e-02       9.693837e-01
# 25298        1.608308e-05      9.999778e-01       6.104092e-06
# 29962        5.505725e-06      1.027896e-02       9.897155e-01
# 78624        2.199114e-09      4.256767e-10       1.000000e+00
# 52723        1.570418e-07      2.706698e-07       9.999996e-01
# 41688        8.990368e-05      9.999006e-01       9.492700e-06
# 83948        4.198938e-05      9.999243e-01       3.373481e-05
#
# [10 rows x 30 columns]

# %%
min_time_published  = news_df["time_published"].min()
max_time_published  = news_df["time_published"].max()

print(min_time_published)
print(max_time_published)
# Out:
# 2022-03-01 08:00:00
# 2023-03-31 16:32:05

# %% [markdown]
# ## Holding period
#
# - 30_minutes
# - 1_hour
# - 1_day
# - 5_day
#
# Edge cases
# - Start of holding period is outside trading hours
#     - Start: End of last trading day price
#     - End: First price after holding period
# - Start of holding period is within trading hours but end of holding period is after trading hours
#     - Start: Price right before the news
#     - End: First price after holding period

# %%
min_datetime = stock_df.index.get_level_values(1).min()
max_datetime = stock_df.index.get_level_values(1).max()

def fill_missing_minutes(df, method):
    """
    Forward/backward fill missing minutes.
    """
    df.reset_index(level="symbol", drop=True, inplace=True)
    index = pd.date_range(start=min_datetime, end=max_datetime, freq='5T')
    # reindex and forward fill 
    filled_df = df.reindex(index, method=method)
    filled_df.index.name = "datetime"
    return filled_df

ffill_stock_df = stock_df.groupby("symbol").apply(fill_missing_minutes, method="ffill").rename(columns={"close":"ffill"})
bfill_stock_df = stock_df.groupby("symbol").apply(fill_missing_minutes, method="bfill").rename(columns={"close":"bfill"})

# %%
# a_stock_df = pd.concat([ffill_stock_df.loc['A'], bfill_stock_df.loc['A'], stock_df.loc['A']], axis=1)

# a_stock_df.loc[a_stock_df['close'].isna()]

# a_stock_df.loc['2022-02-25'].tail(50)

# %%
holding_period_list = ["30_minutes", "1_hour", "1_day", "5_day"]

for holding_period in holding_period_list:
    value, unit = holding_period.split("_")
    news_df["time_published_hold"] = news_df["time_published"] + pd.Timedelta(value=float(value), unit=unit)

    news_df["time_published_before"] = news_df["time_published"].dt.floor("5T")
    news_df[f"time_published_after_{holding_period}"] = news_df["time_published_hold"].dt.ceil("5T")

# %%
cols = [f"time_published_after_{holding_period}" for holding_period in holding_period_list]
news_df[["time_published", "time_published_before"] + cols]
# Out:
#            time_published time_published_before  \
# 0     2022-03-08 23:00:11   2022-03-08 23:00:00
# 1     2022-03-15 22:00:18   2022-03-15 22:00:00
# 2     2022-03-15 08:00:00   2022-03-15 08:00:00
# 3     2022-03-04 15:24:00   2022-03-04 15:20:00
# 4     2022-03-21 22:15:23   2022-03-21 22:15:00
# ...                   ...                   ...
# 88162 2023-02-10 23:45:00   2023-02-10 23:45:00
# 88163 2023-03-01 21:28:00   2023-03-01 21:25:00
# 88164 2023-03-13 19:06:41   2023-03-13 19:05:00
# 88165 2023-03-21 18:00:54   2023-03-21 18:00:00
# 88166 2023-03-30 20:01:07   2023-03-30 20:00:00
#
#       time_published_after_30_minutes time_published_after_1_hour  \
# 0                 2022-03-08 23:35:00         2022-03-09 00:05:00
# 1                 2022-03-15 22:35:00         2022-03-15 23:05:00
# 2                 2022-03-15 08:30:00         2022-03-15 09:00:00
# 3                 2022-03-04 15:55:00         2022-03-04 16:25:00
# 4                 2022-03-21 22:50:00         2022-03-21 23:20:00
# ...                               ...                         ...
# 88162             2023-02-11 00:15:00         2023-02-11 00:45:00
# 88163             2023-03-01 22:00:00         2023-03-01 22:30:00
# 88164             2023-03-13 19:40:00         2023-03-13 20:10:00
# 88165             2023-03-21 18:35:00         2023-03-21 19:05:00
# 88166             2023-03-30 20:35:00         2023-03-30 21:05:00
#
#       time_published_after_1_day time_published_after_5_day
# 0            2022-03-09 23:05:00        2022-03-13 23:05:00
# 1            2022-03-16 22:05:00        2022-03-20 22:05:00
# 2            2022-03-16 08:00:00        2022-03-20 08:00:00
# 3            2022-03-05 15:25:00        2022-03-09 15:25:00
# 4            2022-03-22 22:20:00        2022-03-26 22:20:00
# ...                          ...                        ...
# 88162        2023-02-11 23:45:00        2023-02-15 23:45:00
# 88163        2023-03-02 21:30:00        2023-03-06 21:30:00
# 88164        2023-03-14 19:10:00        2023-03-18 19:10:00
# 88165        2023-03-22 18:05:00        2023-03-26 18:05:00
# 88166        2023-03-31 20:05:00        2023-04-04 20:05:00
#
# [88167 rows x 6 columns]

# %%
news_stock_df = news_df.merge(
    ffill_stock_df, left_on=["symbol", "time_published_before"], right_index=True, how="left").rename(
    columns={"ffill":"price_before"}
)

for holding_period in holding_period_list:
    news_stock_df = news_stock_df.merge(
        bfill_stock_df, left_on=["symbol", f"time_published_after_{holding_period}"], right_index=True, how="left").rename(
        columns={"bfill":f"price_after_{holding_period}"})
    
for holding_period in holding_period_list:
    news_stock_df[f"pct_return_{holding_period}"] = news_stock_df[f"price_after_{holding_period}"] / news_stock_df["price_before"] - 1

# %%
cols = [f"pct_return_{holding_period}" for holding_period in holding_period_list]
news_stock_full_df = news_stock_df.dropna(subset=cols)

# %%
news_stock_full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86537 entries, 0 to 88165
# Data columns (total 45 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   index                            86537 non-null  int64
#  1   title                            86537 non-null  object
#  2   url                              86537 non-null  object
#  3   time_published                   86537 non-null  datetime64[ns]
#  4   authors                          86537 non-null  object
#  5   summary                          86536 non-null  object
#  6   banner_image                     85728 non-null  object
#  7   source                           86537 non-null  object
#  8   category_within_source           19948 non-null  object
#  9   source_domain                    86537 non-null  object
#  10  topics                           86537 non-null  object
#  11  overall_sentiment_score          86537 non-null  float64
#  12  overall_sentiment_label          86537 non-null  object
#  13  ticker_sentiment                 86537 non-null  object
#  14  company                          86537 non-null  object
#  15  symbol                           86537 non-null  object
#  16  relevance_score                  86537 non-null  float64
#  17  ticker_sentiment_score           86537 non-null  float64
#  18  ticker_sentiment_label           86537 non-null  object
#  19  model_input                      86537 non-null  object
#  20  lexicon_neg                      86537 non-null  float64
#  21  lexicon_neu                      86537 non-null  float64
#  22  lexicon_pos                      86537 non-null  float64
#  23  lexicon_compound                 86537 non-null  float64
#  24  finbertv1_negative               86537 non-null  float64
#  25  finbertv1_neutral                86537 non-null  float64
#  26  finbertv1_positive               86537 non-null  float64
#  27  finbertv2_Negative               86537 non-null  float64
#  28  finbertv2_Neutral                86537 non-null  float64
#  29  finbertv2_Positive               86537 non-null  float64
#  30  time_published_hold              86537 non-null  datetime64[ns]
#  31  time_published_before            86537 non-null  datetime64[ns]
#  32  time_published_after_30_minutes  86537 non-null  datetime64[ns]
#  33  time_published_after_1_hour      86537 non-null  datetime64[ns]
#  34  time_published_after_1_day       86537 non-null  datetime64[ns]
#  35  time_published_after_5_day       86537 non-null  datetime64[ns]
#  36  price_before                     86537 non-null  float64
#  37  price_after_30_minutes           86537 non-null  float64
#  38  price_after_1_hour               86537 non-null  float64
#  39  price_after_1_day                86537 non-null  float64
#  40  price_after_5_day                86537 non-null  float64
#  41  pct_return_30_minutes            86537 non-null  float64
#  42  pct_return_1_hour                86537 non-null  float64
#  43  pct_return_1_day                 86537 non-null  float64
#  44  pct_return_5_day                 86537 non-null  float64
# dtypes: datetime64[ns](7), float64(22), int64(1), object(15)
# memory usage: 30.4+ MB

# %%
news_stock_full_df.to_csv("holding_period.csv", index=False)
