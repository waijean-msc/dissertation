# %% [markdown]
# ### Loughran-McDonald

# %%
import pandas as pd

# %%
df = pd.read_csv("Loughran-McDonald_MasterDictionary_1993-2021.csv")

# %%
df
# Out:
#             Word  Seq_num  Word Count  Word Proportion  Average Proportion  \
# 0       AARDVARK        1         354     1.550080e-08        1.422600e-08
# 1      AARDVARKS        2           3     1.313627e-10        8.653817e-12
# 2          ABACI        3           9     3.940882e-10        1.169679e-10
# 3          ABACK        4          29     1.269840e-09        6.654735e-10
# 4         ABACUS        5        8570     3.752595e-07        3.809464e-07
# ...          ...      ...         ...              ...                 ...
# 86526     ZYGOTE    86529          50     2.189379e-09        8.729336e-10
# 86527    ZYGOTES    86530           1     4.378757e-11        1.809516e-11
# 86528    ZYGOTIC    86531           0     0.000000e+00        0.000000e+00
# 86529  ZYMURGIES    86532           0     0.000000e+00        0.000000e+00
# 86530    ZYMURGY    86533           0     0.000000e+00        0.000000e+00
#
#             Std Dev  Doc Count  Negative  Positive  Uncertainty  Litigious  \
# 0      3.815486e-06         99         0         0            0          0
# 1      9.241714e-09          1         0         0            0          0
# 2      5.290465e-08          7         0         0            0          0
# 3      1.595100e-07         28         0         0            0          0
# 4      3.529356e-05       1108         0         0            0          0
# ...             ...        ...       ...       ...          ...        ...
# 86526  1.886011e-07         35         0         0            0          0
# 86527  1.932446e-08          1         0         0            0          0
# 86528  0.000000e+00          0         0         0            0          0
# 86529  0.000000e+00          0         0         0            0          0
# 86530  0.000000e+00          0         0         0            0          0
#
#        Strong_Modal  Weak_Modal  Constraining  Syllables     Source
# 0                 0           0             0          2  12of12inf
# 1                 0           0             0          2  12of12inf
# 2                 0           0             0          3  12of12inf
# 3                 0           0             0          2  12of12inf
# 4                 0           0             0          3  12of12inf
# ...             ...         ...           ...        ...        ...
# 86526             0           0             0          2  12of12inf
# 86527             0           0             0          2  12of12inf
# 86528             0           0             0          3  12of12inf
# 86529             0           0             0          3  12of12inf
# 86530             0           0             0          3  12of12inf
#
# [86531 rows x 16 columns]

# %%
# If a word is included in the sentiment category, the year/version when it was included is indicated. 
# If the year is preceded by a negative sign, this flag indicates the year when the word was removed from the sentiment category.
negative_df = df.loc[df["Negative"] > 0]
positive_df = df.loc[df["Positive"] > 0]

# %%
negative_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2345 entries, 9 to 86094
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Word                2345 non-null   object
#  1   Seq_num             2345 non-null   int64
#  2   Word Count          2345 non-null   int64
#  3   Word Proportion     2345 non-null   float64
#  4   Average Proportion  2345 non-null   float64
#  5   Std Dev             2345 non-null   float64
#  6   Doc Count           2345 non-null   int64
#  7   Negative            2345 non-null   int64
#  8   Positive            2345 non-null   int64
#  9   Uncertainty         2345 non-null   int64
#  10  Litigious           2345 non-null   int64
#  11  Strong_Modal        2345 non-null   int64
#  12  Weak_Modal          2345 non-null   int64
#  13  Constraining        2345 non-null   int64
#  14  Syllables           2345 non-null   int64
#  15  Source              2345 non-null   object
# dtypes: float64(3), int64(11), object(2)
# memory usage: 311.4+ KB

# %%
positive_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 347 entries, 125 to 85942
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Word                347 non-null    object
#  1   Seq_num             347 non-null    int64
#  2   Word Count          347 non-null    int64
#  3   Word Proportion     347 non-null    float64
#  4   Average Proportion  347 non-null    float64
#  5   Std Dev             347 non-null    float64
#  6   Doc Count           347 non-null    int64
#  7   Negative            347 non-null    int64
#  8   Positive            347 non-null    int64
#  9   Uncertainty         347 non-null    int64
#  10  Litigious           347 non-null    int64
#  11  Strong_Modal        347 non-null    int64
#  12  Weak_Modal          347 non-null    int64
#  13  Constraining        347 non-null    int64
#  14  Syllables           347 non-null    int64
#  15  Source              347 non-null    object
# dtypes: float64(3), int64(11), object(2)
# memory usage: 46.1+ KB

# %%
positive_df
# Out:
#              Word  Seq_num  Word Count  Word Proportion  Average Proportion  \
# 125          ABLE      126     4888882     2.140723e-04        2.084159e-04
# 336     ABUNDANCE      337        8438     3.694795e-07        3.733143e-07
# 338      ABUNDANT      339       12804     5.606561e-07        5.145855e-07
# 438     ACCLAIMED      439        2296     1.005363e-07        9.100194e-08
# 477    ACCOMPLISH      478      191204     8.372359e-06        8.782697e-06
# ...           ...      ...         ...              ...                 ...
# 85283         WIN    85286      107701     4.715965e-06        4.759933e-06
# 85405      WINNER    85408       12717     5.568466e-07        6.147755e-07
# 85406     WINNERS    85409        9778     4.281549e-07        5.369742e-07
# 85407     WINNING    85410       57332     2.510429e-06        2.031028e-06
# 85942      WORTHY    85945       18244     7.988605e-07        8.307447e-07
#
#         Std Dev  Doc Count  Negative  Positive  Uncertainty  Litigious  \
# 125    0.000301     725330         0      2009            0          0
# 336    0.000009       6688         0      2009            0          0
# 338    0.000009       9354         0      2009            0          0
# 438    0.000003       1703         0      2009            0          0
# 477    0.000043     128370         0      2009            0          0
# ...         ...        ...       ...       ...          ...        ...
# 85283  0.000077      37321         0      2009            0          0
# 85405  0.000023       5482         0      2009            0          0
# 85406  0.000030       4019         0      2009            0          0
# 85407  0.000026      29809         0      2009            0          0
# 85942  0.000011      14523         0      2009            0          0
#
#        Strong_Modal  Weak_Modal  Constraining  Syllables     Source
# 125               0           0             0          2  12of12inf
# 336               0           0             0          3  12of12inf
# 338               0           0             0          3  12of12inf
# 438               0           0             0          2  12of12inf
# 477               0           0             0          3  12of12inf
# ...             ...         ...           ...        ...        ...
# 85283             0           0             0          1  12of12inf
# 85405             0           0             0          2  12of12inf
# 85406             0           0             0          2  12of12inf
# 85407             0           0             0          2  12of12inf
# 85942             0           0             0          2  12of12inf
#
# [347 rows x 16 columns]

# %% [markdown]
# ### Vader

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
sentences = ["VADER is smart, handsome, and funny.",  # positive sentence example
             "VADER is smart, handsome, and funny!",  # punctuation emphasis handled correctly (sentiment intensity adjusted)
             "VADER is very smart, handsome, and funny.", # booster words handled correctly (sentiment intensity adjusted)
             "VADER is VERY SMART, handsome, and FUNNY.",  # emphasis for ALLCAPS handled
             "VADER is VERY SMART, handsome, and FUNNY!!!", # combination of signals - VADER appropriately adjusts intensity
             "VADER is VERY SMART, uber handsome, and FRIGGIN FUNNY!!!", # booster words & punctuation make this close to ceiling for score
             "VADER is not smart, handsome, nor funny.",  # negation sentence example
             "The book was good.",  # positive sentence
             "At least it isn't a horrible book.",  # negated negative sentence with contraction
             "The book was only kind of good.", # qualified positive sentence is handled correctly (intensity adjusted)
             "The plot was good, but the characters are uncompelling and the dialog is not great.", # mixed negation sentence
             "Today SUX!",  # negative slang with capitalization emphasis
             "Today only kinda sux! But I'll get by, lol", # mixed sentiment example with slang and constrastive conjunction "but"
             "Make sure you :) or :D today!",  # emoticons handled
             "Catch utf-8 emoji such as such as 💘 and 💋 and 😁",  # emojis handled
             "Not bad at all"  # Capitalized negation
             ]

analyzer = SentimentIntensityAnalyzer()
for sentence in sentences:
    vs = analyzer.polarity_scores(sentence)
    print("{:-<65} {}".format(sentence, str(vs)))
# Out:
# VADER is smart, handsome, and funny.----------------------------- {'neg': 0.0, 'neu': 0.254, 'pos': 0.746, 'compound': 0.8316}
# VADER is smart, handsome, and funny!----------------------------- {'neg': 0.0, 'neu': 0.248, 'pos': 0.752, 'compound': 0.8439}
# VADER is very smart, handsome, and funny.------------------------ {'neg': 0.0, 'neu': 0.299, 'pos': 0.701, 'compound': 0.8545}
# VADER is VERY SMART, handsome, and FUNNY.------------------------ {'neg': 0.0, 'neu': 0.246, 'pos': 0.754, 'compound': 0.9227}
# VADER is VERY SMART, handsome, and FUNNY!!!---------------------- {'neg': 0.0, 'neu': 0.233, 'pos': 0.767, 'compound': 0.9342}
# VADER is VERY SMART, uber handsome, and FRIGGIN FUNNY!!!--------- {'neg': 0.0, 'neu': 0.294, 'pos': 0.706, 'compound': 0.9469}
# VADER is not smart, handsome, nor funny.------------------------- {'neg': 0.646, 'neu': 0.354, 'pos': 0.0, 'compound': -0.7424}
# The book was good.----------------------------------------------- {'neg': 0.0, 'neu': 0.508, 'pos': 0.492, 'compound': 0.4404}
# At least it isn't a horrible book.------------------------------- {'neg': 0.0, 'neu': 0.637, 'pos': 0.363, 'compound': 0.431}
# The book was only kind of good.---------------------------------- {'neg': 0.0, 'neu': 0.697, 'pos': 0.303, 'compound': 0.3832}
# The plot was good, but the characters are uncompelling and the dialog is not great. {'neg': 0.327, 'neu': 0.579, 'pos': 0.094, 'compound': -0.7042}
# Today SUX!------------------------------------------------------- {'neg': 0.779, 'neu': 0.221, 'pos': 0.0, 'compound': -0.5461}
# Today only kinda sux! But I'll get by, lol----------------------- {'neg': 0.127, 'neu': 0.556, 'pos': 0.317, 'compound': 0.5249}
# Make sure you :) or :D today!------------------------------------ {'neg': 0.0, 'neu': 0.294, 'pos': 0.706, 'compound': 0.8633}
# Catch utf-8 emoji such as such as 💘 and 💋 and 😁------------------ {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Not bad at all--------------------------------------------------- {'neg': 0.0, 'neu': 0.513, 'pos': 0.487, 'compound': 0.431}

# %% [markdown]
# ### Vader from NLTK

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

new_words = {
    'foo': 2.0,
    'bar': -3.4,
}

sia = SentimentIntensityAnalyzer()

sia.lexicon.update(new_words)

# %%
sia.lexicon["cancer"]
# Out:
# -3.4

# %%
for sentence in sentences:
    score = sia.polarity_scores(sentence)
    print("{:<} \n{}".format(sentence, str(score)))
# Out:
# VADER is smart, handsome, and funny.
# {'neg': 0.0, 'neu': 0.254, 'pos': 0.746, 'compound': 0.8316}
# VADER is smart, handsome, and funny!
# {'neg': 0.0, 'neu': 0.248, 'pos': 0.752, 'compound': 0.8439}
# VADER is very smart, handsome, and funny.
# {'neg': 0.0, 'neu': 0.299, 'pos': 0.701, 'compound': 0.8545}
# VADER is VERY SMART, handsome, and FUNNY.
# {'neg': 0.0, 'neu': 0.246, 'pos': 0.754, 'compound': 0.9227}
# VADER is VERY SMART, handsome, and FUNNY!!!
# {'neg': 0.0, 'neu': 0.233, 'pos': 0.767, 'compound': 0.9342}
# VADER is VERY SMART, uber handsome, and FRIGGIN FUNNY!!!
# {'neg': 0.0, 'neu': 0.294, 'pos': 0.706, 'compound': 0.9469}
# VADER is not smart, handsome, nor funny.
# {'neg': 0.646, 'neu': 0.354, 'pos': 0.0, 'compound': -0.7424}
# The book was good.
# {'neg': 0.0, 'neu': 0.508, 'pos': 0.492, 'compound': 0.4404}
# At least it isn't a horrible book.
# {'neg': 0.0, 'neu': 0.637, 'pos': 0.363, 'compound': 0.431}
# The book was only kind of good.
# {'neg': 0.0, 'neu': 0.697, 'pos': 0.303, 'compound': 0.3832}
# The plot was good, but the characters are uncompelling and the dialog is not great.
# {'neg': 0.327, 'neu': 0.579, 'pos': 0.094, 'compound': -0.7042}
# Today SUX!
# {'neg': 0.779, 'neu': 0.221, 'pos': 0.0, 'compound': -0.5461}
# Today only kinda sux! But I'll get by, lol
# {'neg': 0.127, 'neu': 0.556, 'pos': 0.317, 'compound': 0.5249}
# Make sure you :) or :D today!
# {'neg': 0.0, 'neu': 0.294, 'pos': 0.706, 'compound': 0.8633}
# Catch utf-8 emoji such as such as 💘 and 💋 and 😁
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Not bad at all
# {'neg': 0.0, 'neu': 0.513, 'pos': 0.487, 'compound': 0.431}

# %%
lm_negative_list = [word.lower() for word in negative_df["Word"].to_list()]
lm_positive_list = [word.lower() for word in positive_df["Word"].to_list()]

# %%
# how to set the valence score
lm_negative_dict = {word:-1 for word in lm_negative_list}
lm_positive_dict = {word:1 for word in lm_positive_list}

# %%
sia.lexicon.clear()
sia.lexicon.update(lm_negative_dict)
sia.lexicon.update(lm_positive_dict)

# %%
sia.lexicon
# Out:
# {'abandon': -1,
#  'abandoned': -1,
#  'abandoning': -1,
#  'abandonment': -1,
#  'abandonments': -1,
#  'abandons': -1,
#  'abdicated': -1,
#  'abdicates': -1,
#  'abdicating': -1,
#  'abdication': -1,
#  'abdications': -1,
#  'aberrant': -1,
#  'aberration': -1,
#  'aberrational': -1,
#  'aberrations': -1,
#  'abetting': -1,
#  'abnormal': -1,
#  'abnormalities': -1,
#  'abnormality': -1,
#  'abnormally': -1,
#  'abolish': -1,
#  'abolished': -1,
#  'abolishes': -1,
#  'abolishing': -1,
#  'abrogate': -1,
#  'abrogated': -1,
#  'abrogates': -1,
#  'abrogating': -1,
#  'abrogation': -1,
#  'abrogations': -1,
#  'abrupt': -1,
#  'abruptly': -1,
#  'abruptness': -1,
#  'absence': -1,
#  'absences': -1,
#  'absenteeism': -1,
#  'abuse': -1,
#  'abused': -1,
#  'abuses': -1,
#  'abusing': -1,
#  'abusive': -1,
#  'abusively': -1,
#  'abusiveness': -1,
#  'accident': -1,
#  'accidental': -1,
#  'accidentally': -1,
#  'accidents': -1,
#  'accusation': -1,
#  'accusations': -1,
#  'accuse': -1,
#  'accused': -1,
#  'accuses': -1,
#  'accusing': -1,
#  'acquiesce': -1,
#  'acquiesced': -1,
#  'acquiesces': -1,
#  'acquiescing': -1,
#  'acquit': -1,
#  'acquits': -1,
#  'acquittal': -1,
#  'acquittals': -1,
#  'acquitted': -1,
#  'acquitting': -1,
#  'adulterate': -1,
#  'adulterated': -1,
#  'adulterating': -1,
#  'adulteration': -1,
#  'adulterations': -1,
#  'adversarial': -1,
#  'adversaries': -1,
#  'adversary': -1,
#  'adverse': -1,
#  'adversely': -1,
#  'adversities': -1,
#  'adversity': -1,
#  'aftermath': -1,
#  'aftermaths': -1,
#  'against': -1,
#  'aggravate': -1,
#  'aggravated': -1,
#  'aggravates': -1,
#  'aggravating': -1,
#  'aggravation': -1,
#  'aggravations': -1,
#  'alerted': -1,
#  'alerting': -1,
#  'alienate': -1,
#  'alienated': -1,
#  'alienates': -1,
#  'alienating': -1,
#  'alienation': -1,
#  'alienations': -1,
#  'allegation': -1,
#  'allegations': -1,
#  'allege': -1,
#  'alleged': -1,
#  'allegedly': -1,
#  'alleges': -1,
#  'alleging': -1,
#  'annoy': -1,
#  'annoyance': -1,
#  'annoyances': -1,
#  'annoyed': -1,
#  'annoying': -1,
#  'annoys': -1,
#  'annul': -1,
#  'annulled': -1,
#  'annulling': -1,
#  'annulment': -1,
#  'annulments': -1,
#  'annuls': -1,
#  'anomalies': -1,
#  'anomalous': -1,
#  'anomalously': -1,
#  'anomaly': -1,
#  'anticompetitive': -1,
#  'antitrust': -1,
#  'argue': -1,
#  'argued': -1,
#  'arguing': -1,
#  'argument': -1,
#  'argumentative': -1,
#  'arguments': -1,
#  'arrearage': -1,
#  'arrearages': -1,
#  'arrears': -1,
#  'arrest': -1,
#  'arrested': -1,
#  'arrests': -1,
#  'artificially': -1,
#  'assault': -1,
#  'assaulted': -1,
#  'assaulting': -1,
#  'assaults': -1,
#  'assertions': -1,
#  'attrition': -1,
#  'aversely': -1,
#  'backdating': -1,
#  'bad': -1,
#  'bail': -1,
#  'bailout': -1,
#  'balk': -1,
#  'balked': -1,
#  'bankrupt': -1,
#  'bankruptcies': -1,
#  'bankruptcy': -1,
#  'bankrupted': -1,
#  'bankrupting': -1,
#  'bankrupts': -1,
#  'bans': -1,
#  'barred': -1,
#  'barrier': -1,
#  'barriers': -1,
#  'bottleneck': -1,
#  'bottlenecks': -1,
#  'boycott': -1,
#  'boycotted': -1,
#  'boycotting': -1,
#  'boycotts': -1,
#  'breach': -1,
#  'breached': -1,
#  'breaches': -1,
#  'breaching': -1,
#  'break': -1,
#  'breakage': -1,
#  'breakages': -1,
#  'breakdown': -1,
#  'breakdowns': -1,
#  'breaks': -1,
#  'bribe': -1,
#  'bribed': -1,
#  'briberies': -1,
#  'bribery': -1,
#  'bribes': -1,
#  'bribing': -1,
#  'burden': -1,
#  'burdened': -1,
#  'burdening': -1,
#  'burdens': -1,
#  'burdensome': -1,
#  'burned': -1,
#  'calamities': -1,
#  'calamitous': -1,
#  'calamity': -1,
#  'cancel': -1,
#  'canceled': -1,
#  'canceling': -1,
#  'cancellation': -1,
#  'cancellations': -1,
#  'cancelled': -1,
#  'cancelling': -1,
#  'cancels': -1,
#  'careless': -1,
#  'carelessly': -1,
#  'carelessness': -1,
#  'catastrophe': -1,
#  'catastrophes': -1,
#  'catastrophic': -1,
#  'catastrophically': -1,
#  'caution': -1,
#  'cautionary': -1,
#  'cautioned': -1,
#  'cautioning': -1,
#  'cautions': -1,
#  'cease': -1,
#  'ceased': -1,
#  'ceases': -1,
#  'ceasing': -1,
#  'censure': -1,
#  'censured': -1,
#  'censures': -1,
#  'censuring': -1,
#  'challenge': -1,
#  'challenged': -1,
#  'challenges': -1,
#  'challenging': -1,
#  'chargeoffs': -1,
#  'circumvent': -1,
#  'circumvented': -1,
#  'circumventing': -1,
#  'circumvention': -1,
#  'circumventions': -1,
#  'circumvents': -1,
#  'claiming': -1,
#  'claims': -1,
#  'clawback': -1,
#  'closeout': -1,
#  'closeouts': -1,
#  'closings': -1,
#  'closure': -1,
#  'closures': -1,
#  'coerce': -1,
#  'coerced': -1,
#  'coerces': -1,
#  'coercing': -1,
#  'coercion': -1,
#  'coercive': -1,
#  'collapse': -1,
#  'collapsed': -1,
#  'collapses': -1,
#  'collapsing': -1,
#  'collision': -1,
#  'collisions': -1,
#  'collude': -1,
#  'colluded': -1,
#  'colludes': -1,
#  'colluding': -1,
#  'collusion': -1,
#  'collusions': -1,
#  'collusive': -1,
#  'complain': -1,
#  'complained': -1,
#  'complaining': -1,
#  'complains': -1,
#  'complaint': -1,
#  'complaints': -1,
#  'complicate': -1,
#  'complicated': -1,
#  'complicates': -1,
#  'complicating': -1,
#  'complication': -1,
#  'complications': -1,
#  'compulsion': -1,
#  'concealed': -1,
#  'concealing': -1,
#  'concede': -1,
#  'conceded': -1,
#  'concedes': -1,
#  'conceding': -1,
#  'concern': -1,
#  'concerned': -1,
#  'concerns': -1,
#  'conciliating': -1,
#  'conciliation': -1,
#  'conciliations': -1,
#  'condemn': -1,
#  'condemnation': -1,
#  'condemnations': -1,
#  'condemned': -1,
#  'condemning': -1,
#  'condemns': -1,
#  'condone': -1,
#  'condoned': -1,
#  'confess': -1,
#  'confessed': -1,
#  'confesses': -1,
#  'confessing': -1,
#  'confession': -1,
#  'confine': -1,
#  'confined': -1,
#  'confinement': -1,
#  'confinements': -1,
#  'confines': -1,
#  'confining': -1,
#  'confiscate': -1,
#  'confiscated': -1,
#  'confiscates': -1,
#  'confiscating': -1,
#  'confiscation': -1,
#  'confiscations': -1,
#  'conflict': -1,
#  'conflicted': -1,
#  'conflicting': -1,
#  'conflicts': -1,
#  'confront': -1,
#  'confrontation': -1,
#  'confrontational': -1,
#  'confrontations': -1,
#  'confronted': -1,
#  'confronting': -1,
#  'confronts': -1,
#  'confuse': -1,
#  'confused': -1,
#  'confuses': -1,
#  'confusing': -1,
#  'confusingly': -1,
#  'confusion': -1,
#  'conspiracies': -1,
#  'conspiracy': -1,
#  'conspirator': -1,
#  'conspiratorial': -1,
#  'conspirators': -1,
#  'conspire': -1,
#  'conspired': -1,
#  'conspires': -1,
#  'conspiring': -1,
#  'contempt': -1,
#  'contend': -1,
#  'contended': -1,
#  'contending': -1,
#  'contends': -1,
#  'contention': -1,
#  'contentions': -1,
#  'contentious': -1,
#  'contentiously': -1,
#  'contested': -1,
#  'contesting': -1,
#  'contraction': -1,
#  'contractions': -1,
#  'contradict': -1,
#  'contradicted': -1,
#  'contradicting': -1,
#  'contradiction': -1,
#  'contradictions': -1,
#  'contradictory': -1,
#  'contradicts': -1,
#  'contrary': -1,
#  'controversial': -1,
#  'controversies': -1,
#  'controversy': -1,
#  'convict': -1,
#  'convicted': -1,
#  'convicting': -1,
#  'conviction': -1,
#  'convictions': -1,
#  'corrected': -1,
#  'correcting': -1,
#  'correction': -1,
#  'corrections': -1,
#  'corrects': -1,
#  'corrupt': -1,
#  'corrupted': -1,
#  'corrupting': -1,
#  'corruption': -1,
#  'corruptions': -1,
#  'corruptly': -1,
#  'corruptness': -1,
#  'costly': -1,
#  'counterclaim': -1,
#  'counterclaimed': -1,
#  'counterclaiming': -1,
#  'counterclaims': -1,
#  'counterfeit': -1,
#  'counterfeited': -1,
#  'counterfeiter': -1,
#  'counterfeiters': -1,
#  'counterfeiting': -1,
#  'counterfeits': -1,
#  'countermeasure': -1,
#  'countermeasures': -1,
#  'crime': -1,
#  'crimes': -1,
#  'criminal': -1,
#  'criminally': -1,
#  'criminals': -1,
#  'crises': -1,
#  'crisis': -1,
#  'critically': -1,
#  'criticism': -1,
#  'criticisms': -1,
#  'criticize': -1,
#  'criticized': -1,
#  'criticizes': -1,
#  'criticizing': -1,
#  'crucial': -1,
#  'crucially': -1,
#  'culpability': -1,
#  'culpable': -1,
#  'culpably': -1,
#  'cumbersome': -1,
#  'curtail': -1,
#  'curtailed': -1,
#  'curtailing': -1,
#  'curtailment': -1,
#  'curtailments': -1,
#  'curtails': -1,
#  'cut': -1,
#  'cutback': -1,
#  'cutbacks': -1,
#  'cyberattack': -1,
#  'cyberattacks': -1,
#  'cyberbullying': -1,
#  'cybercrime': -1,
#  'cybercrimes': -1,
#  'cybercriminal': -1,
#  'cybercriminals': -1,
#  'damage': -1,
#  'damaged': -1,
#  'damages': -1,
#  'damaging': -1,
#  'dampen': -1,
#  'dampened': -1,
#  'danger': -1,
#  'dangerous': -1,
#  'dangerously': -1,
#  'dangers': -1,
#  'deadlock': -1,
#  'deadlocked': -1,
#  'deadlocking': -1,
#  'deadlocks': -1,
#  'deadweight': -1,
#  'deadweights': -1,
#  'debarment': -1,
#  'debarments': -1,
#  'debarred': -1,
#  'deceased': -1,
#  'deceit': -1,
#  'deceitful': -1,
#  'deceitfulness': -1,
#  'deceive': -1,
#  'deceived': -1,
#  'deceives': -1,
#  'deceiving': -1,
#  'deception': -1,
#  'deceptions': -1,
#  'deceptive': -1,
#  'deceptively': -1,
#  'decline': -1,
#  'declined': -1,
#  'declines': -1,
#  'declining': -1,
#  'deface': -1,
#  'defaced': -1,
#  'defacement': -1,
#  'defamation': -1,
#  'defamations': -1,
#  'defamatory': -1,
#  'defame': -1,
#  'defamed': -1,
#  'defames': -1,
#  'defaming': -1,
#  'default': -1,
#  'defaulted': -1,
#  'defaulting': -1,
#  'defaults': -1,
#  'defeat': -1,
#  'defeated': -1,
#  'defeating': -1,
#  'defeats': -1,
#  'defect': -1,
#  'defective': -1,
#  'defects': -1,
#  'defend': -1,
#  'defendant': -1,
#  'defendants': -1,
#  'defended': -1,
#  'defending': -1,
#  'defends': -1,
#  'defensive': -1,
#  'defer': -1,
#  'deficiencies': -1,
#  'deficiency': -1,
#  'deficient': -1,
#  'deficit': -1,
#  'deficits': -1,
#  'defraud': -1,
#  'defrauded': -1,
#  'defrauding': -1,
#  'defrauds': -1,
#  'defunct': -1,
#  'degradation': -1,
#  'degradations': -1,
#  'degrade': -1,
#  'degraded': -1,
#  'degrades': -1,
#  'degrading': -1,
#  'delay': -1,
#  'delayed': -1,
#  'delaying': -1,
#  'delays': -1,
#  'deleterious': -1,
#  'deliberate': -1,
#  'deliberated': -1,
#  'deliberately': -1,
#  'delinquencies': -1,
#  'delinquency': -1,
#  'delinquent': -1,
#  'delinquently': -1,
#  'delinquents': -1,
#  'delist': -1,
#  'delisted': -1,
#  'delisting': -1,
#  'delists': -1,
#  'demise': -1,
#  'demised': -1,
#  'demises': -1,
#  'demising': -1,
#  'demolish': -1,
#  'demolished': -1,
#  'demolishes': -1,
#  'demolishing': -1,
#  'demolition': -1,
#  'demolitions': -1,
#  'demote': -1,
#  'demoted': -1,
#  'demotes': -1,
#  'demoting': -1,
#  'demotion': -1,
#  'demotions': -1,
#  'denial': -1,
#  'denials': -1,
#  'denied': -1,
#  'denies': -1,
#  'denigrate': -1,
#  'denigrated': -1,
#  'denigrates': -1,
#  'denigrating': -1,
#  'denigration': -1,
#  'deny': -1,
#  'denying': -1,
#  'deplete': -1,
#  'depleted': -1,
#  'depletes': -1,
#  'depleting': -1,
#  'depletion': -1,
#  'depletions': -1,
#  'deprecation': -1,
#  'depress': -1,
#  'depressed': -1,
#  'depresses': -1,
#  'depressing': -1,
#  'deprivation': -1,
#  'deprive': -1,
#  'deprived': -1,
#  'deprives': -1,
#  'depriving': -1,
#  'derelict': -1,
#  'dereliction': -1,
#  'derogatory': -1,
#  'destabilization': -1,
#  'destabilize': -1,
#  'destabilized': -1,
#  'destabilizing': -1,
#  'destroy': -1,
#  'destroyed': -1,
#  'destroying': -1,
#  'destroys': -1,
#  'destruction': -1,
#  'destructive': -1,
#  'detain': -1,
#  'detained': -1,
#  'detention': -1,
#  'detentions': -1,
#  'deter': -1,
#  'deteriorate': -1,
#  'deteriorated': -1,
#  'deteriorates': -1,
#  'deteriorating': -1,
#  'deterioration': -1,
#  'deteriorations': -1,
#  'deterred': -1,
#  'deterrence': -1,
#  'deterrences': -1,
#  'deterrent': -1,
#  'deterrents': -1,
#  'deterring': -1,
#  'deters': -1,
#  'detract': -1,
#  'detracted': -1,
#  'detracting': -1,
#  'detriment': -1,
#  'detrimental': -1,
#  'detrimentally': -1,
#  'detriments': -1,
#  'devalue': -1,
#  'devalued': -1,
#  'devalues': -1,
#  'devaluing': -1,
#  'devastate': -1,
#  'devastated': -1,
#  'devastating': -1,
#  'devastation': -1,
#  'deviate': -1,
#  'deviated': -1,
#  'deviates': -1,
#  'deviating': -1,
#  'deviation': -1,
#  'deviations': -1,
#  'devolve': -1,
#  'devolved': -1,
#  'devolves': -1,
#  'devolving': -1,
#  'difficult': -1,
#  'difficulties': -1,
#  'difficultly': -1,
#  'difficulty': -1,
#  'diminish': -1,
#  'diminished': -1,
#  'diminishes': -1,
#  'diminishing': -1,
#  'diminution': -1,
#  'disadvantage': -1,
#  'disadvantaged': -1,
#  'disadvantageous': -1,
#  'disadvantages': -1,
#  'disaffiliation': -1,
#  'disagree': -1,
#  'disagreeable': -1,
#  'disagreed': -1,
#  'disagreeing': -1,
#  'disagreement': -1,
#  'disagreements': -1,
#  'disagrees': -1,
#  'disallow': -1,
#  'disallowance': -1,
#  'disallowances': -1,
#  'disallowed': -1,
#  'disallowing': -1,
#  'disallows': -1,
#  'disappear': -1,
#  'disappearance': -1,
#  'disappearances': -1,
#  'disappeared': -1,
#  'disappearing': -1,
#  'disappears': -1,
#  'disappoint': -1,
#  'disappointed': -1,
#  'disappointing': -1,
#  'disappointingly': -1,
#  'disappointment': -1,
#  'disappointments': -1,
#  'disappoints': -1,
#  'disapproval': -1,
#  'disapprovals': -1,
#  'disapprove': -1,
#  'disapproved': -1,
#  'disapproves': -1,
#  'disapproving': -1,
#  'disassociates': -1,
#  'disassociating': -1,
#  'disassociation': -1,
#  'disassociations': -1,
#  'disaster': -1,
#  'disasters': -1,
#  'disastrous': -1,
#  'disastrously': -1,
#  'disavow': -1,
#  'disavowal': -1,
#  'disavowed': -1,
#  'disavowing': -1,
#  'disavows': -1,
#  'disciplinary': -1,
#  'disclaim': -1,
#  'disclaimed': -1,
#  'disclaimer': -1,
#  'disclaimers': -1,
#  'disclaiming': -1,
#  'disclaims': -1,
#  'disclose': -1,
#  'disclosed': -1,
#  'discloses': -1,
#  'disclosing': -1,
#  'discontinuance': -1,
#  'discontinuances': -1,
#  'discontinuation': -1,
#  'discontinuations': -1,
#  'discontinue': -1,
#  'discontinued': -1,
#  'discontinues': -1,
#  'discontinuing': -1,
#  'discourage': -1,
#  'discouraged': -1,
#  'discourages': -1,
#  'discouraging': -1,
#  'discredit': -1,
#  'discredited': -1,
#  'discrediting': -1,
#  'discredits': -1,
#  'discrepancies': -1,
#  'discrepancy': -1,
#  'disfavor': -1,
#  'disfavored': -1,
#  'disfavoring': -1,
#  'disfavors': -1,
#  'disgorge': -1,
#  'disgorged': -1,
#  'disgorgement': -1,
#  'disgorgements': -1,
#  'disgorges': -1,
#  'disgorging': -1,
#  'disgrace': -1,
#  'disgraceful': -1,
#  'disgracefully': -1,
#  'dishonest': -1,
#  'dishonestly': -1,
#  'dishonesty': -1,
#  'dishonor': -1,
#  'dishonorable': -1,
#  'dishonorably': -1,
#  'dishonored': -1,
#  'dishonoring': -1,
#  'dishonors': -1,
#  'disincentives': -1,
#  'disinterested': -1,
#  'disinterestedly': -1,
#  'disinterestedness': -1,
#  'disloyal': -1,
#  'disloyally': -1,
#  'disloyalty': -1,
#  'dismal': -1,
#  'dismally': -1,
#  'dismiss': -1,
#  'dismissal': -1,
#  'dismissals': -1,
#  'dismissed': -1,
#  'dismisses': -1,
#  'dismissing': -1,
#  'disorderly': -1,
#  'disparage': -1,
#  'disparaged': -1,
#  'disparagement': -1,
#  'disparagements': -1,
#  'disparages': -1,
#  'disparaging': -1,
#  'disparagingly': -1,
#  'disparities': -1,
#  'disparity': -1,
#  'displace': -1,
#  'displaced': -1,
#  'displacement': -1,
#  'displacements': -1,
#  'displaces': -1,
#  'displacing': -1,
#  'dispose': -1,
#  'dispossess': -1,
#  'dispossessed': -1,
#  'dispossesses': -1,
#  'dispossessing': -1,
#  'disproportion': -1,
#  'disproportional': -1,
#  'disproportionate': -1,
#  'disproportionately': -1,
#  'dispute': -1,
#  'disputed': -1,
#  'disputes': -1,
#  'disputing': -1,
#  'disqualification': -1,
#  'disqualifications': -1,
#  'disqualified': -1,
#  'disqualifies': -1,
#  'disqualify': -1,
#  'disqualifying': -1,
#  'disregard': -1,
#  'disregarded': -1,
#  'disregarding': -1,
#  'disregards': -1,
#  'disreputable': -1,
#  'disrepute': -1,
#  'disrupt': -1,
#  'disrupted': -1,
#  'disrupting': -1,
#  'disruption': -1,
#  'disruptions': -1,
#  'disruptive': -1,
#  'disrupts': -1,
#  'dissatisfaction': -1,
#  'dissatisfied': -1,
#  'dissent': -1,
#  'dissented': -1,
#  'dissenter': -1,
#  'dissenters': -1,
#  'dissenting': -1,
#  'dissents': -1,
#  'dissident': -1,
#  'dissidents': -1,
#  'dissolution': -1,
#  'dissolutions': -1,
#  'distort': -1,
#  'distorted': -1,
#  'distorting': -1,
#  'distortion': -1,
#  'distortions': -1,
#  'distorts': -1,
#  'distract': -1,
#  'distracted': -1,
#  'distracting': -1,
#  'distraction': -1,
#  'distractions': -1,
#  'distracts': -1,
#  'distress': -1,
#  'distressed': -1,
#  'disturb': -1,
#  'disturbance': -1,
#  'disturbances': -1,
#  'disturbed': -1,
#  'disturbing': -1,
#  'disturbs': -1,
#  'diversion': -1,
#  'divert': -1,
#  'diverted': -1,
#  'diverting': -1,
#  'diverts': -1,
#  'divest': -1,
#  'divested': -1,
#  'divesting': -1,
#  'divestiture': -1,
#  'divestitures': -1,
#  'divestment': -1,
#  'divestments': -1,
#  'divests': -1,
#  'divorce': -1,
#  'divorced': -1,
#  'divulge': -1,
#  'divulged': -1,
#  'divulges': -1,
#  'divulging': -1,
#  'doubt': -1,
#  'doubted': -1,
#  'doubtful': -1,
#  'doubts': -1,
#  'downgrade': -1,
#  'downgraded': -1,
#  'downgrades': -1,
#  'downgrading': -1,
#  'downsize': -1,
#  'downsized': -1,
#  'downsizes': -1,
#  'downsizing': -1,
#  'downsizings': -1,
#  'downtime': -1,
#  'downtimes': -1,
#  'downturn': -1,
#  'downturns': -1,
#  'downward': -1,
#  'downwards': -1,
#  'drag': -1,
#  'drastic': -1,
#  'drastically': -1,
#  'drawback': -1,
#  'drawbacks': -1,
#  'dropped': -1,
#  'drought': -1,
#  'droughts': -1,
#  'duress': -1,
#  'dysfunction': -1,
#  'dysfunctional': -1,
#  'dysfunctions': -1,
#  'easing': -1,
#  'egregious': -1,
#  'egregiously': -1,
#  'embargo': -1,
#  'embargoed': -1,
#  'embargoes': -1,
#  'embargoing': -1,
#  'embarrass': -1,
#  'embarrassed': -1,
#  'embarrasses': -1,
#  'embarrassing': -1,
#  'embarrassment': -1,
#  'embarrassments': -1,
#  'embezzle': -1,
#  'embezzled': -1,
#  'embezzlement': -1,
#  'embezzlements': -1,
#  'embezzler': -1,
#  'embezzles': -1,
#  'embezzling': -1,
#  'encroach': -1,
#  'encroached': -1,
#  'encroaches': -1,
#  'encroaching': -1,
#  'encroachment': -1,
#  'encroachments': -1,
#  'encumber': -1,
#  'encumbered': -1,
#  'encumbering': -1,
#  'encumbers': -1,
#  'encumbrance': -1,
#  'encumbrances': -1,
#  'endanger': -1,
#  'endangered': -1,
#  'endangering': -1,
#  'endangerment': -1,
#  'endangers': -1,
#  'enjoin': -1,
#  'enjoined': -1,
#  'enjoining': -1,
#  'enjoins': -1,
#  'erode': -1,
#  'eroded': -1,
#  'erodes': -1,
#  'eroding': -1,
#  'erosion': -1,
#  'erratic': -1,
#  'erratically': -1,
#  'erred': -1,
#  'erring': -1,
#  'erroneous': -1,
#  'erroneously': -1,
#  'error': -1,
#  'errors': -1,
#  'errs': -1,
#  'escalate': -1,
#  'escalated': -1,
#  'escalates': -1,
#  'escalating': -1,
#  'evade': -1,
#  'evaded': -1,
#  'evades': -1,
#  'evading': -1,
#  'evasion': -1,
#  'evasions': -1,
#  'evasive': -1,
#  'evict': -1,
#  'evicted': -1,
#  'evicting': -1,
#  'eviction': -1,
#  'evictions': -1,
#  'evicts': -1,
#  'exacerbate': -1,
#  'exacerbated': -1,
#  'exacerbates': -1,
#  'exacerbating': -1,
#  'exacerbation': -1,
#  'exacerbations': -1,
#  'exaggerate': -1,
#  'exaggerated': -1,
#  'exaggerates': -1,
#  'exaggerating': -1,
#  'exaggeration': -1,
#  'excessive': -1,
#  'excessively': -1,
#  'exculpate': -1,
#  'exculpated': -1,
#  'exculpates': -1,
#  'exculpating': -1,
#  'exculpation': -1,
#  'exculpations': -1,
#  'exculpatory': -1,
#  'exonerate': -1,
#  'exonerated': -1,
#  'exonerates': -1,
#  'exonerating': -1,
#  'exoneration': -1,
#  'exonerations': -1,
#  'exploit': -1,
#  'exploitation': -1,
#  'exploitations': -1,
#  'exploitative': -1,
#  'exploited': -1,
#  'exploiting': -1,
#  'exploits': -1,
#  'expose': -1,
#  'exposed': -1,
#  'exposes': -1,
#  'exposing': -1,
#  'expropriate': -1,
#  'expropriated': -1,
#  'expropriates': -1,
#  'expropriating': -1,
#  'expropriation': -1,
#  'expropriations': -1,
#  'expulsion': -1,
#  'expulsions': -1,
#  'extenuating': -1,
#  'fail': -1,
#  'failed': -1,
#  'failing': -1,
#  'failings': -1,
#  'fails': -1,
#  'failure': -1,
#  'failures': -1,
#  'fallout': -1,
#  'false': -1,
#  'falsely': -1,
#  'falsification': -1,
#  'falsifications': -1,
#  'falsified': -1,
#  'falsifies': -1,
#  'falsify': -1,
#  ...}

# %%
sentence = "Winner in financial crisis"
score = sia.polarity_scores(sentence)
print("{:<} \n{}".format(sentence, str(score)))
# Out:
# Winner in financial crisis
# {'neg': 0.333, 'neu': 0.333, 'pos': 0.333, 'compound': 0.0}
