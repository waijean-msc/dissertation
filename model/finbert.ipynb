# %%
import pandas as pd

# %% [markdown]
# ## Data

# %%
df = pd.read_csv("../news_stock_price.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145689 entries, 0 to 145688
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   title                    145689 non-null  object
#  1   url                      145689 non-null  object
#  2   time_published           145689 non-null  object
#  3   authors                  145689 non-null  object
#  4   summary                  145677 non-null  object
#  5   banner_image             141418 non-null  object
#  6   source                   145689 non-null  object
#  7   category_within_source   46206 non-null   object
#  8   source_domain            145689 non-null  object
#  9   topics                   145689 non-null  object
#  10  overall_sentiment_score  145689 non-null  float64
#  11  overall_sentiment_label  145689 non-null  object
#  12  ticker_sentiment         145689 non-null  object
#  13  company                  145689 non-null  object
#  14  symbol                   145689 non-null  object
#  15  time_published_5min      145689 non-null  object
#  16  date                     145689 non-null  object
#  17  datetime_before          145689 non-null  object
#  18  open                     145689 non-null  float64
#  19  high                     145689 non-null  float64
#  20  low                      145689 non-null  float64
#  21  close_before             145689 non-null  float64
#  22  volume                   145689 non-null  float64
#  23  datetime_after           145689 non-null  object
#  24  close_after              145689 non-null  float64
#  25  pct_return               145689 non-null  float64
# dtypes: float64(8), object(18)
# memory usage: 28.9+ MB

# %%
df
# Out:
#                                                     title  \
# 0       Schwab  ( SCHW )  February Client Assets Fall ...
# 1       Should Schwab Fundamental U.S. Small Company I...
# 2       Schwab  ( SCHW )  Expands Crypto Exposure, Fil...
# 3       Women deserve respect around money and investi...
# 4                  Is Charles Schwab Stock Fairly Priced?
# ...                                                   ...
# 145684  Ericsson  ( ERIC )  Sets Up Quantum Research H...
# 145685  Here's Why Juniper  ( JNPR )  is a Healthy Inv...
# 145686  Arista  ( ANET )  Offers Improved, Modernized ...
# 145687  5G IoT Market worth $59.7 billion by 2028 - Ex...
# 145688  Buy These 4 Mutual Funds to Protect Against Ma...
#
#                                                       url  \
# 0       https://www.zacks.com/stock/news/1882042/schwa...
# 1       https://www.zacks.com/stock/news/1879406/shoul...
# 2       https://www.zacks.com/stock/news/1877593/schwa...
# 3       https://www.marketwatch.com/story/women-deserv...
# 4       https://www.forbes.com/sites/greatspeculations...
# ...                                                   ...
# 145684  https://www.zacks.com/stock/news/2068552/erics...
# 145685  https://www.zacks.com/stock/news/2069118/heres...
# 145686  https://www.zacks.com/stock/news/2069120/arist...
# 145687  https://www.prnewswire.com/news-releases/5g-io...
# 145688  https://www.zacks.com/stock/news/2066579/buy-t...
#
#              time_published                        authors  \
# 0       2022-03-15 12:22:00  ['Zacks Investment Research']
# 1       2022-03-09 11:20:06  ['Zacks Investment Research']
# 2       2022-03-04 15:24:00  ['Zacks Investment Research']
# 3       2022-03-09 12:10:00    ['Carrie Schwab-Pomerantz']
# 4       2022-03-25 10:30:34                ['Trefis Team']
# ...                     ...                            ...
# 145684  2023-03-21 13:08:00  ['Zacks Investment Research']
# 145685  2023-03-22 14:09:00  ['Zacks Investment Research']
# 145686  2023-03-22 14:11:00  ['Zacks Investment Research']
# 145687  2023-03-24 14:30:00          ['MarketsandMarkets']
# 145688  2023-03-16 11:10:00  ['Zacks Investment Research']
#
#                                                   summary  \
# 0       Unfavorable markets hurt Schwab's (SCHW) total...
# 1                           Style Box ETF report for FNDA
# 2       Schwab (SCHW) files for a crypto economy ETF w...
# 3       Sexism and stereotypes deter women from buildi...
# 4       Charles Schwab's stock has gained roughly 7% Y...
# ...                                                   ...
# 145684  Ericsson's (ERIC) quantum research hub is like...
# 145685  Juniper (JNPR) is set to capitalize on the gro...
# 145686  The Arista (ANET) solution will enable custome...
# 145687  5G IoT Market worth $59.7 billion by 2028 - Ex...
# 145688  Invest in mutual funds like FSUTX, PRUZX, FRUA...
#
#                                              banner_image            source  \
# 0       https://staticx-tuner.zacks.com/images/article...  Zacks Commentary
# 1       https://staticx-tuner.zacks.com/images/default...  Zacks Commentary
# 2       https://staticx-tuner.zacks.com/images/article...  Zacks Commentary
# 3                https://images.mktw.net/im-496327/social       MarketWatch
# 4       https://imageio.forbes.com/specials-images/ima...            Forbes
# ...                                                   ...               ...
# 145684  https://staticx-tuner.zacks.com/images/article...  Zacks Commentary
# 145685  https://staticx-tuner.zacks.com/images/article...  Zacks Commentary
# 145686  https://staticx-tuner.zacks.com/images/article...  Zacks Commentary
# 145687  https://mma.prnewswire.com/media/660509/Market...       PR Newswire
# 145688  https://staticx-tuner.zacks.com/images/article...  Zacks Commentary
#
#        category_within_source        source_domain  \
# 0                         NaN        www.zacks.com
# 1                         NaN        www.zacks.com
# 2                         NaN        www.zacks.com
# 3                 Top Stories  www.marketwatch.com
# 4                     Markets       www.forbes.com
# ...                       ...                  ...
# 145684                    NaN        www.zacks.com
# 145685                    NaN        www.zacks.com
# 145686                    NaN        www.zacks.com
# 145687                    NaN   www.prnewswire.com
# 145688                    NaN        www.zacks.com
#
#                                                    topics  ...  \
# 0       [{'topic': 'Earnings', 'relevance_score': '0.3...  ...
# 1       [{'topic': 'Retail & Wholesale', 'relevance_sc...  ...
# 2       [{'topic': 'Financial Markets', 'relevance_sco...  ...
# 3       [{'topic': 'Earnings', 'relevance_score': '0.1...  ...
# 4       [{'topic': 'Earnings', 'relevance_score': '0.9...  ...
# ...                                                   ...  ...
# 145684  [{'topic': 'Earnings', 'relevance_score': '0.9...  ...
# 145685  [{'topic': 'Financial Markets', 'relevance_sco...  ...
# 145686  [{'topic': 'Financial Markets', 'relevance_sco...  ...
# 145687  [{'topic': 'Earnings', 'relevance_score': '0.1...  ...
# 145688  [{'topic': 'Economy - Monetary', 'relevance_sc...  ...
#
#                        date      datetime_before        open        high  \
# 0       2022-03-15 00:00:00  2022-03-15 12:20:00   81.808661   81.867943
# 1       2022-03-09 00:00:00  2022-03-09 11:20:00   77.619426   77.915834
# 2       2022-03-04 00:00:00  2022-03-04 15:20:00   77.303257   77.490982
# 3       2022-03-09 00:00:00  2022-03-09 12:10:00   78.133200   78.172721
# 4       2022-03-25 00:00:00  2022-03-25 10:30:00   89.762281   89.875904
# ...                     ...                  ...         ...         ...
# 145684  2023-03-21 00:00:00  2023-03-21 13:05:00  144.560000  144.570000
# 145685  2023-03-22 00:00:00  2023-03-22 14:05:00  144.720000  145.060000
# 145686  2023-03-22 00:00:00  2023-03-22 14:10:00  144.920000  145.290000
# 145687  2023-03-24 00:00:00  2023-03-24 14:30:00  142.110000  142.270000
# 145688  2023-03-16 00:00:00  2023-03-16 11:10:00  141.995000  142.260000
#
#                low close_before    volume       datetime_after  close_after  \
# 0        81.749380    81.803721   33783.0  2022-03-15 12:45:00    81.937105
# 1        77.550264    77.846672   32667.0  2022-03-09 11:45:00    78.093679
# 2        77.303257    77.352658   62596.0  2022-03-04 15:45:00    77.609545
# 3        77.984996    78.172721   55781.0  2022-03-09 12:35:00    78.548171
# 4        89.678299    89.851204   68042.0  2022-03-25 10:55:00    90.177253
# ...            ...          ...       ...                  ...          ...
# 145684  144.440000   144.500000   30848.0  2023-03-21 13:30:00   144.900000
# 145685  144.660000   144.905000   77348.0  2023-03-22 14:30:00   145.060000
# 145686  144.890000   144.930000   56872.0  2023-03-22 14:35:00   145.000000
# 145687  142.070000   142.255000   33217.0  2023-03-24 14:55:00   142.320000
# 145688  141.970000   142.235000  130655.0  2023-03-16 11:35:00   141.580000
#
#         pct_return
# 0         0.001631
# 1         0.003173
# 2         0.003321
# 3         0.004803
# 4         0.003629
# ...            ...
# 145684    0.002768
# 145685    0.001070
# 145686    0.000483
# 145687    0.000457
# 145688   -0.004605
#
# [145689 rows x 26 columns]

# %% [markdown]
# ## Finbert (Prosus AI)
#
# https://huggingface.co/ProsusAI/finbert

# %%
import torch

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

tokenizer = AutoTokenizer.from_pretrained("ProsusAI/finbert")

model = AutoModelForSequenceClassification.from_pretrained("ProsusAI/finbert")

softmax = torch.nn.Softmax(dim=-1)

# %% [markdown]
# ## Single sentence
#
# #LABEL_0: positive; LABEL_1: negative; LABEL_2: neutral

# %%
def process_single_sentence(tokenizer, model, softmax, sentence, verbose=True):
    inputs = tokenizer(sentence, return_tensors="pt")
    if verbose:
        print(f"Tokens: {inputs}\n")
    outputs = model(**inputs)
    if verbose:
        print(f"Logits: {outputs.logits}")
    prob = softmax(outputs.logits)
    return prob

# %%
sentences = ["Stocks rallied and the British pound gained.", "profits are flat"]

for sent in sentences:
    print(sent)
    prob = process_single_sentence(tokenizer, model, softmax, sent, verbose=False)
    print(prob)
    print("\n")
# Out:
# Stocks rallied and the British pound gained.
# tensor([[0.8984, 0.0345, 0.0672]], grad_fn=<SoftmaxBackward0>)
#
#
# profits are flat
# tensor([[0.2225, 0.0589, 0.7186]], grad_fn=<SoftmaxBackward0>)

# %% [markdown]
# ## Multiple sentences

# %%
def process_multiple_sentence(tokenizer, model, softmax, sentences, verbose=True):
    inputs = tokenizer(sentences, return_tensors="pt", padding=True)
    if verbose:
        print(f"Tokens: {inputs}\n")
    outputs = model(**inputs)
    if verbose:
        print(f"Logits: {outputs.logits}")
    prob = softmax(outputs.logits)
    return prob

# %%
sentences = ["Stocks rallied and the British pound gained.", "profits are flat"]
process_multiple_sentence(tokenizer, model, softmax, sentences, verbose=False)
# Out:
# tensor([[0.8984, 0.0345, 0.0672],
#         [0.2225, 0.0589, 0.7186]], grad_fn=<SoftmaxBackward0>)

# %% [markdown]
# ## Finbert (yiyanghkust)
#
# https://huggingface.co/yiyanghkust/finbert-tone
#
# #LABEL_0: neutral; LABEL_1: positive; LABEL_2: negative

# %%
from transformers import BertTokenizer, BertForSequenceClassification
from transformers import pipeline

tokenizer = BertTokenizer.from_pretrained('yiyanghkust/finbert-tone')

model = BertForSequenceClassification.from_pretrained('yiyanghkust/finbert-tone',num_labels=3)

softmax = torch.nn.Softmax(dim=-1)
# nlp = pipeline("sentiment-analysis", model=finbert, tokenizer=tokenizer)

# %% [markdown]
# ## Single sentence

# %%
sentences = ["there is a shortage of capital, and we need extra financing",  
             "growth is strong and we have plenty of liquidity", 
             "there are doubts about our finances", 
             "profits are flat"]

for sent in sentences:
    print(sent)
    prob = process_single_sentence(tokenizer, model, softmax, sent, verbose=False)
    print(prob)
    print("\n")
# Out:
# there is a shortage of capital, and we need extra financing
# tensor([[3.3754e-03, 7.2024e-06, 9.9662e-01]], grad_fn=<SoftmaxBackward0>)
#
#
# growth is strong and we have plenty of liquidity
# tensor([[2.6476e-08, 1.0000e+00, 2.1309e-08]], grad_fn=<SoftmaxBackward0>)
#
#
# there are doubts about our finances
# tensor([[2.6841e-05, 2.1086e-06, 9.9997e-01]], grad_fn=<SoftmaxBackward0>)
#
#
# profits are flat
# tensor([[0.9889, 0.0018, 0.0092]], grad_fn=<SoftmaxBackward0>)

# %% [markdown]
# ## Multiple sentences

# %%
sentences = ["there is a shortage of capital, and we need extra financing",  
             "growth is strong and we have plenty of liquidity", 
             "there are doubts about our finances", 
             "profits are flat"]

process_multiple_sentence(tokenizer, model, softmax, sentences, verbose=False)
# Out:
# tensor([[3.3754e-03, 7.2024e-06, 9.9662e-01],
#         [2.6475e-08, 1.0000e+00, 2.1309e-08],
#         [2.6841e-05, 2.1086e-06, 9.9997e-01],
#         [9.8894e-01, 1.8429e-03, 9.2129e-03]], grad_fn=<SoftmaxBackward0>)
